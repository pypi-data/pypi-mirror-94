# %% [markdown]
# # Usage
#
# To use the UNFCCC API, import the package and instantiate the reader,
# which will download the most recent metadata from the UNFCCC:

# %%
import unfccc_di_api

reader = unfccc_di_api.UNFCCCApiReader()

# %% [markdown]
# Check for which parties data is available:

# %%
reader.parties
# Out:
#        code                name noData
# id
# 3       AUS           Australia    NaN
# 4       AUT             Austria    NaN
# 5       BEL             Belgium    NaN
# 6       BGR            Bulgaria    NaN
# 7       BLR             Belarus    NaN
# ...     ...                 ...    ...
# 100214  VNM            Viet Nam    NaN
# 100215  YEM               Yemen    NaN
# 100216  ZMB              Zambia    NaN
# 100217  ZWE            Zimbabwe    NaN
# 100229  PSE  State of Palestine    NaN
#
# [198 rows x 3 columns]

# %% [markdown]
# Access all data for a specific party:

# %%
reader.query(party_code="AFG")
# Out:
#     party                    category      classification  \
# 0     AFG                  1.  Energy  Total for category
# 1     AFG                  1.  Energy  Total for category
# 2     AFG                  1.  Energy  Total for category
# 3     AFG                  1.  Energy  Total for category
# 4     AFG                  1.  Energy  Total for category
# ..    ...                         ...                 ...
# 374   AFG  unknown category nr. 10504  Total for category
# 375   AFG  unknown category nr. 10504  Total for category
# 376   AFG  unknown category nr. 10504  Total for category
# 377   AFG  unknown category nr. 10504  Total for category
# 378   AFG  unknown category nr. 10504  Total for category
#
#                     measure             gas               unit  year  \
# 0    Net emissions/removals  Aggregate GHGs  Gg CO2 equivalent  2005
# 1    Net emissions/removals  Aggregate GHGs  Gg CO2 equivalent  2013
# 2    Net emissions/removals             CH4                 Gg  2005
# 3    Net emissions/removals             CH4                 Gg  2013
# 4    Net emissions/removals              CO                 Gg  2005
# ..                      ...             ...                ...   ...
# 374        Total population          No gas          thousands  2014
# 375        Total population          No gas          thousands  2015
# 376        Total population          No gas          thousands  2016
# 377        Total population          No gas          thousands  2017
# 378        Total population          No gas          thousands  2018
#
#      numberValue stringValue
# 0     3776.15946        None
# 1    10281.00000        None
# 2       35.06076        None
# 3        4.00000        None
# 4      865.20000        None
# ..           ...         ...
# 374  26556.75400        None
# 375  27101.36500        None
# 376  27657.14500        None
# 377  28224.32300        None
# 378  30075.01800        None
#
# [379 rows x 9 columns]

# %% [markdown]
# Queries can be more specific, e.g. selecting only data about one gas:

# %%
reader.query(party_code="DEU", gases=["N₂O"])
# Out:
#       party                            category      classification  \
# 0       DEU                          1.  Energy  Total for category
# 1       DEU                          1.  Energy  Total for category
# 2       DEU                          1.  Energy  Total for category
# 3       DEU                          1.  Energy  Total for category
# 4       DEU                          1.  Energy  Total for category
# ...     ...                                 ...                 ...
# 34168   DEU  Total GHG emissions without LULUCF  Total for category
# 34169   DEU  Total GHG emissions without LULUCF  Total for category
# 34170   DEU  Total GHG emissions without LULUCF  Total for category
# 34171   DEU  Total GHG emissions without LULUCF  Total for category
# 34172   DEU  Total GHG emissions without LULUCF  Total for category
#
#                            measure  gas     unit       year  numberValue  \
# 0      Emission factor information  N2O  no unit       1990          NaN
# 1      Emission factor information  N2O  no unit       1991          NaN
# 2      Emission factor information  N2O  no unit       1992          NaN
# 3      Emission factor information  N2O  no unit       1993          NaN
# 4      Emission factor information  N2O  no unit       1994          NaN
# ...                            ...  ...      ...        ...          ...
# 34168       Net emissions/removals  N2O       kt       2015   129.755265
# 34169       Net emissions/removals  N2O       kt       2016   126.960736
# 34170       Net emissions/removals  N2O       kt       2017   125.976196
# 34171       Net emissions/removals  N2O       kt       2018   119.188881
# 34172       Net emissions/removals  N2O       kt  Base year   209.808203
#
#       stringValue
# 0          CS,D,M
# 1          CS,D,M
# 2          CS,D,M
# 3          CS,D,M
# 4          CS,D,M
# ...           ...
# 34168        None
# 34169        None
# 34170        None
# 34171        None
# 34172        None
#
# [34173 rows x 9 columns]

# %% [markdown]
# Queries can be made much more specific, if you want to. Check the API
# docs section (next section), or the docstrings for details.
